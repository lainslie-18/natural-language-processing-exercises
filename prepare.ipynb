# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
import numpy as np

from time import strftime

import acquire

# %% [markdown]
# # Exercise 1
#
# Define a function named `basic_clean`. It should take in a string and apply some basic text cleaning to it:
#
# * Lowercase everything
#
# * Normalize unicode characters
#
# * Replace anything that is not a letter, number, whitespace or a single quote.

# %%
def basic_clean(str):
    '''
    This function takes in a string and converts all characters to lowercase, normalizes them, removes special
    characters, and returns a string
    '''
    # convert all to lowercase
    str = str.lower()
    # normalize
    str = unicodedata.normalize('NFKD', str)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')
    # remove anything that is not a letter, number, single quote, or white space
    str = re.sub(r"[^a-z0-9'\s]", '', str)
    
    return str

# %% [markdown]
# # Exercise 2
#
# Define a function named `tokenize`. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(str):
    '''
    This function takes in a string and uses a tokenizer to break words, punctuation, etc. into discrete units
    '''
    # create tokenize item
    tokenizer = nltk.tokenize.ToktokTokenizer()
    # apply tokenizer to str and assign result to variable 'str'
    str = tokenizer.tokenize(str, return_str=True)
    
    return str

# %% [markdown]
# # Exercise 3
#
# Define a function named `stem`. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(str):
    '''
    This function takes in a string and uses a stemmer object to attempt to convert words to their base form
    '''
    # create the stemmer object
    ps = nltk.porter.PorterStemmer()
    # split string and loop through each word to apply stemmer
    stems = [ps.stem(word) for word in str.split()]
    # join the split and stemmed words back together on a space
    str = ' '.join(stems)
    
    return str

# %% [markdown]
# # Exercise 4
#
# Define a function named `lemmatize`. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(str):
    '''
    This function takes in a string and uses a lemmatizer object to attempt to convert words to their root word
    '''
    # create the lemmatizer object
    wnl = nltk.stem.WordNetLemmatizer()
    # split string and loop through each word to apply lemmatizer
    lemmas = [wnl.lemmatize(word) for word in str.split()]
    # join the split and lemmatized words back together on a space
    str = ' '.join(lemmas)
    
    return str

# %% [markdown]
# # Exercise 5
#
# Define a function named `remove_stopwords`. It should accept some text and return the text after removing all the stopwords.

# %%
def remove_stopwords(str, extra_words=[], exclude_words=[]):
    '''
    This function takes in a string and removes words that have little or no significance
    '''
    # pull in english stopwords and assign to a variable
    stopword_list = stopwords.words('english')
    # extend stopword_list if additional words are specified
    if extra_words:
        stopword_list = stopword_list.extend(extra_words)
        # remove words if exclusion words are specified
    if exclude_words:
        stopword_list = [stopword_list.remove(word) for word in exclude_words]
    # split string to create a list of words
    words = str.split()
    # filter out words that are not in stopword list
    not_stopwords = [w for w in words if w not in stopword_list]
    
    str = ' '.join(not_stopwords)
    
    return str

# %% [markdown]
# # Exercise 6
#
# Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe `news_df`.

# %%
# use function to pull in dataframe
news_df = acquire.read_news_articles(refresh = False)
news_df
# Out:
#                                                 title  \
# 0   RBI cancels licence of Maha-based Independence...
# 1           Boost to EVs a big step: Windmill Capital
# 2   Facebook parent Meta's $230-billion wipeout bi...
# 3   Tesla co-worker used N-word, threw a hot tool ...
# 4   Mark Zuckerberg loses $31 bn in one of the big...
# ..                                                ...
# 95  Greatest blessing: Riteish wishes Genelia on 1...
# 96  I don't care about all that: Jim Sarbh on soci...
# 97  'Bunty Aur Babli 2' numbers disappointing, but...
# 98  Court directs Honey Singh to give voice sample...
# 99  Not my style: Deepika on being asked if she ga...
#
#                                               content       category
# 0   RBI has cancelled licence of Maharashtra-based...       business
# 1   Increased use of EVs in public transport, spec...       business
# 2   Facebook's parent Meta's shares plunged 27% an...       business
# 3   A former Tesla worker has filed a lawsuit agai...       business
# 4   Meta CEO Mark Zuckerberg's wealth dropped by $...       business
# ..                                                ...            ...
# 95  Actor Riteish Deshmukh on Thursday marked his ...  entertainment
# 96  Actor Jim Sarbh, on being asked about craving ...  entertainment
# 97  Actress Sharvari Wagh, who made her debut in '...  entertainment
# 98  Rapper Yo Yo Honey Singh has been directed by ...  entertainment
# 99  When asked if she had given any special dating...  entertainment
#
# [100 rows x 3 columns]

# %% [markdown]
# # Exercise 7
#
# Make another dataframe for the Codeup blog posts. Name the dataframe `codeup_df`.

# %%
# use function to pull in dataframe
codeup_df = acquire.read_blog_articles(refresh = False)
codeup_df
# Out:
#                                                 title  \
# 0   VET TEC Funding Now Available For Dallas Veterans
# 1       Dallas Campus Re-opens With New Grant Partner
# 2   Is Codeup the Best Bootcamp in San Antonio…or ...
# 3            Codeup Launches First Podcast: Hire Tech
# 4                   Codeup Start Dates for March 2022
# 5   VET TEC Funding Now Available For Dallas Veterans
# 6       Dallas Campus Re-opens With New Grant Partner
# 7                            Codeup Dallas Open House
# 8   Codeup’s Placement Team Continues Setting Records
# 9   IT Certifications 101: Why They Matter, and Wh...
# 10  A rise in cyber attacks means opportunities fo...
# 11   Use your GI Bill® benefits to Land a Job in Tech
# 12  Which program is right for me: Cyber Security ...
# 13               What the Heck is System Engineering?
# 14     From Speech Pathology to Business Intelligence
# 15                      Boris – Behind the Billboards
# 16  Is Codeup the Best Bootcamp in San Antonio…or ...
# 17           Codeup Launches First Podcast: Hire Tech
# 18        Why Should I Become a System Administrator?
# 19        Announcing our Candidacy for Accreditation!
# 20  Codeup Takes Over More of the Historic Vogue B...
# 21  Inclusion at Codeup During Pride Month (and Al...
#
#                                                  link  \
# 0   https://codeup.com/codeup-news/vet-tec-funding...
# 1   https://codeup.com/codeup-news/dallas-campus-r...
# 2   https://codeup.com/codeup-news/is-codeup-the-b...
# 3   https://codeup.com/codeup-news/codeup-launches...
# 4   https://codeup.com/codeup-news/codeup-start-da...
# 5   https://codeup.com/codeup-news/vet-tec-funding...
# 6   https://codeup.com/codeup-news/dallas-campus-r...
# 7   https://codeup.com/dallas-newsletter/codeup-da...
# 8   https://codeup.com/codeup-news/codeups-placeme...
# 9   https://codeup.com/it-training/it-certificatio...
# 10  https://codeup.com/cybersecurity/a-rise-in-cyb...
# 11  https://codeup.com/codeup-news/use-your-gi-bil...
# 12  https://codeup.com/tips-for-prospective-studen...
# 13  https://codeup.com/it-training/what-the-heck-i...
# 14  https://codeup.com/alumni-stories/from-speech-...
# 15  https://codeup.com/behind-the-billboards/boris...
# 16  https://codeup.com/codeup-news/is-codeup-the-b...
# 17  https://codeup.com/codeup-news/codeup-launches...
# 18  https://codeup.com/tips-for-prospective-studen...
# 19  https://codeup.com/codeup-news/codeup-candidat...
# 20  https://codeup.com/codeup-news/codeup-takes-ov...
# 21  https://codeup.com/codeup-news/inclusion-at-co...
#
#                                               content
# 0   We are so happy to announce that VET TEC benef...
# 1   We are happy to announce that our Dallas campu...
# 2   Looking for the best data science bootcamp in ...
# 3   Any podcast enthusiasts out there? We are plea...
# 4   As we approach the end of January we wanted to...
# 5   We are so happy to announce that VET TEC benef...
# 6   We are happy to announce that our Dallas campu...
# 7   Come join us for the re-opening of our Dallas ...
# 8   Our Placement Team is simply defined as a grou...
# 9   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 10  In the last few months, the US has experienced...
# 11  As the end of military service gets closer, ma...
# 12  What IT Career should I choose?\nIf you’re thi...
# 13  Codeup offers a 13-week training program: Syst...
# 14  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 15                                                NaN
# 16  Looking for the best data science bootcamp in ...
# 17  Any podcast enthusiasts out there? We are plea...
# 18  With so many tech careers in demand, why choos...
# 19  Did you know that even though we’re an indepen...
# 20  Codeup is moving into another floor of our His...
# 21  Happy Pride Month! Pride Month is a dedicated ...

# %% [markdown]
# # Exercise 8
#
# For each dataframe, produce the following columns:
#
# * `title` to hold the title
#
# * `original` to hold the original article/post content
#
# * `clean` to hold the normalized and tokenized original with the stopwords removed
#
# * `stemmed` to hold the stemmed version of the cleaned data
#
# * `lemmatized` to hold the lemmatized version of the cleaned data

# %% [markdown]
# ### For `news_df`:

# %%
# rename content column to original
news_df = news_df.rename(columns={'content':'original'})

# %%
# create a clean column with functions applied to original to clean and tokenize content
news_df['clean'] = news_df.original.apply(lambda x:basic_clean(x)).apply(lambda x:tokenize(x))

# %%
# create stemmed and lemmatized columns with functions applied to original to further clean
news_df = news_df.assign(stemmed = news_df.clean.apply(stem), lemmatized = news_df.clean.apply(lemmatize))
news_df
# Out:
#                                                 title  \
# 0   RBI cancels licence of Maha-based Independence...
# 1           Boost to EVs a big step: Windmill Capital
# 2   Facebook parent Meta's $230-billion wipeout bi...
# 3   Tesla co-worker used N-word, threw a hot tool ...
# 4   Mark Zuckerberg loses $31 bn in one of the big...
# ..                                                ...
# 95  Greatest blessing: Riteish wishes Genelia on 1...
# 96  I don't care about all that: Jim Sarbh on soci...
# 97  'Bunty Aur Babli 2' numbers disappointing, but...
# 98  Court directs Honey Singh to give voice sample...
# 99  Not my style: Deepika on being asked if she ga...
#
#                                              original       category  \
# 0   RBI has cancelled licence of Maharashtra-based...       business
# 1   Increased use of EVs in public transport, spec...       business
# 2   Facebook's parent Meta's shares plunged 27% an...       business
# 3   A former Tesla worker has filed a lawsuit agai...       business
# 4   Meta CEO Mark Zuckerberg's wealth dropped by $...       business
# ..                                                ...            ...
# 95  Actor Riteish Deshmukh on Thursday marked his ...  entertainment
# 96  Actor Jim Sarbh, on being asked about craving ...  entertainment
# 97  Actress Sharvari Wagh, who made her debut in '...  entertainment
# 98  Rapper Yo Yo Honey Singh has been directed by ...  entertainment
# 99  When asked if she had given any special dating...  entertainment
#
#                                                 clean  \
# 0   rbi has cancelled licence of maharashtrabased ...
# 1   increased use of evs in public transport speci...
# 2   facebook ' s parent meta ' s shares plunged 27...
# 3   a former tesla worker has filed a lawsuit agai...
# 4   meta ceo mark zuckerberg ' s wealth dropped by...
# ..                                                ...
# 95  actor riteish deshmukh on thursday marked his ...
# 96  actor jim sarbh on being asked about craving p...
# 97  actress sharvari wagh who made her debut in ' ...
# 98  rapper yo yo honey singh has been directed by ...
# 99  when asked if she had given any special dating...
#
#                                               stemmed  \
# 0   rbi ha cancel licenc of maharashtrabas indepen...
# 1   increas use of ev in public transport special ...
# 2   facebook ' s parent meta ' s share plung 27 an...
# 3   a former tesla worker ha file a lawsuit agains...
# 4   meta ceo mark zuckerberg ' s wealth drop by 31...
# ..                                                ...
# 95  actor riteish deshmukh on thursday mark hi 10t...
# 96  actor jim sarbh on be ask about crave peopl ' ...
# 97  actress sharvari wagh who made her debut in ' ...
# 98  rapper yo yo honey singh ha been direct by nag...
# 99  when ask if she had given ani special date adv...
#
#                                            lemmatized
# 0   rbi ha cancelled licence of maharashtrabased i...
# 1   increased use of ev in public transport specia...
# 2   facebook ' s parent meta ' s share plunged 27 ...
# 3   a former tesla worker ha filed a lawsuit again...
# 4   meta ceo mark zuckerberg ' s wealth dropped by...
# ..                                                ...
# 95  actor riteish deshmukh on thursday marked his ...
# 96  actor jim sarbh on being asked about craving p...
# 97  actress sharvari wagh who made her debut in ' ...
# 98  rapper yo yo honey singh ha been directed by n...
# 99  when asked if she had given any special dating...
#
# [100 rows x 6 columns]

# %% [markdown]
# ### For `codeup_df`:

# %%
# rename content column to original
codeup_df = codeup_df.rename(columns={'content':'original'})
codeup_df
# Out:
#                                                 title  \
# 0   VET TEC Funding Now Available For Dallas Veterans
# 1       Dallas Campus Re-opens With New Grant Partner
# 2   Is Codeup the Best Bootcamp in San Antonio…or ...
# 3            Codeup Launches First Podcast: Hire Tech
# 4                   Codeup Start Dates for March 2022
# 5   VET TEC Funding Now Available For Dallas Veterans
# 6       Dallas Campus Re-opens With New Grant Partner
# 7                            Codeup Dallas Open House
# 8   Codeup’s Placement Team Continues Setting Records
# 9   IT Certifications 101: Why They Matter, and Wh...
# 10  A rise in cyber attacks means opportunities fo...
# 11   Use your GI Bill® benefits to Land a Job in Tech
# 12  Which program is right for me: Cyber Security ...
# 13               What the Heck is System Engineering?
# 14     From Speech Pathology to Business Intelligence
# 15                      Boris – Behind the Billboards
# 16  Is Codeup the Best Bootcamp in San Antonio…or ...
# 17           Codeup Launches First Podcast: Hire Tech
# 18        Why Should I Become a System Administrator?
# 19        Announcing our Candidacy for Accreditation!
# 20  Codeup Takes Over More of the Historic Vogue B...
# 21  Inclusion at Codeup During Pride Month (and Al...
#
#                                                  link  \
# 0   https://codeup.com/codeup-news/vet-tec-funding...
# 1   https://codeup.com/codeup-news/dallas-campus-r...
# 2   https://codeup.com/codeup-news/is-codeup-the-b...
# 3   https://codeup.com/codeup-news/codeup-launches...
# 4   https://codeup.com/codeup-news/codeup-start-da...
# 5   https://codeup.com/codeup-news/vet-tec-funding...
# 6   https://codeup.com/codeup-news/dallas-campus-r...
# 7   https://codeup.com/dallas-newsletter/codeup-da...
# 8   https://codeup.com/codeup-news/codeups-placeme...
# 9   https://codeup.com/it-training/it-certificatio...
# 10  https://codeup.com/cybersecurity/a-rise-in-cyb...
# 11  https://codeup.com/codeup-news/use-your-gi-bil...
# 12  https://codeup.com/tips-for-prospective-studen...
# 13  https://codeup.com/it-training/what-the-heck-i...
# 14  https://codeup.com/alumni-stories/from-speech-...
# 15  https://codeup.com/behind-the-billboards/boris...
# 16  https://codeup.com/codeup-news/is-codeup-the-b...
# 17  https://codeup.com/codeup-news/codeup-launches...
# 18  https://codeup.com/tips-for-prospective-studen...
# 19  https://codeup.com/codeup-news/codeup-candidat...
# 20  https://codeup.com/codeup-news/codeup-takes-ov...
# 21  https://codeup.com/codeup-news/inclusion-at-co...
#
#                                              original
# 0   We are so happy to announce that VET TEC benef...
# 1   We are happy to announce that our Dallas campu...
# 2   Looking for the best data science bootcamp in ...
# 3   Any podcast enthusiasts out there? We are plea...
# 4   As we approach the end of January we wanted to...
# 5   We are so happy to announce that VET TEC benef...
# 6   We are happy to announce that our Dallas campu...
# 7   Come join us for the re-opening of our Dallas ...
# 8   Our Placement Team is simply defined as a grou...
# 9   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 10  In the last few months, the US has experienced...
# 11  As the end of military service gets closer, ma...
# 12  What IT Career should I choose?\nIf you’re thi...
# 13  Codeup offers a 13-week training program: Syst...
# 14  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 15                                                NaN
# 16  Looking for the best data science bootcamp in ...
# 17  Any podcast enthusiasts out there? We are plea...
# 18  With so many tech careers in demand, why choos...
# 19  Did you know that even though we’re an indepen...
# 20  Codeup is moving into another floor of our His...
# 21  Happy Pride Month! Pride Month is a dedicated ...

# %%
# fill one null value with the reason for it's lack of content
codeup_df.original.fillna('video', inplace=True)
codeup_df
# Out:
#                                                 title  \
# 0   VET TEC Funding Now Available For Dallas Veterans
# 1       Dallas Campus Re-opens With New Grant Partner
# 2   Is Codeup the Best Bootcamp in San Antonio…or ...
# 3            Codeup Launches First Podcast: Hire Tech
# 4                   Codeup Start Dates for March 2022
# 5   VET TEC Funding Now Available For Dallas Veterans
# 6       Dallas Campus Re-opens With New Grant Partner
# 7                            Codeup Dallas Open House
# 8   Codeup’s Placement Team Continues Setting Records
# 9   IT Certifications 101: Why They Matter, and Wh...
# 10  A rise in cyber attacks means opportunities fo...
# 11   Use your GI Bill® benefits to Land a Job in Tech
# 12  Which program is right for me: Cyber Security ...
# 13               What the Heck is System Engineering?
# 14     From Speech Pathology to Business Intelligence
# 15                      Boris – Behind the Billboards
# 16  Is Codeup the Best Bootcamp in San Antonio…or ...
# 17           Codeup Launches First Podcast: Hire Tech
# 18        Why Should I Become a System Administrator?
# 19        Announcing our Candidacy for Accreditation!
# 20  Codeup Takes Over More of the Historic Vogue B...
# 21  Inclusion at Codeup During Pride Month (and Al...
#
#                                                  link  \
# 0   https://codeup.com/codeup-news/vet-tec-funding...
# 1   https://codeup.com/codeup-news/dallas-campus-r...
# 2   https://codeup.com/codeup-news/is-codeup-the-b...
# 3   https://codeup.com/codeup-news/codeup-launches...
# 4   https://codeup.com/codeup-news/codeup-start-da...
# 5   https://codeup.com/codeup-news/vet-tec-funding...
# 6   https://codeup.com/codeup-news/dallas-campus-r...
# 7   https://codeup.com/dallas-newsletter/codeup-da...
# 8   https://codeup.com/codeup-news/codeups-placeme...
# 9   https://codeup.com/it-training/it-certificatio...
# 10  https://codeup.com/cybersecurity/a-rise-in-cyb...
# 11  https://codeup.com/codeup-news/use-your-gi-bil...
# 12  https://codeup.com/tips-for-prospective-studen...
# 13  https://codeup.com/it-training/what-the-heck-i...
# 14  https://codeup.com/alumni-stories/from-speech-...
# 15  https://codeup.com/behind-the-billboards/boris...
# 16  https://codeup.com/codeup-news/is-codeup-the-b...
# 17  https://codeup.com/codeup-news/codeup-launches...
# 18  https://codeup.com/tips-for-prospective-studen...
# 19  https://codeup.com/codeup-news/codeup-candidat...
# 20  https://codeup.com/codeup-news/codeup-takes-ov...
# 21  https://codeup.com/codeup-news/inclusion-at-co...
#
#                                              original
# 0   We are so happy to announce that VET TEC benef...
# 1   We are happy to announce that our Dallas campu...
# 2   Looking for the best data science bootcamp in ...
# 3   Any podcast enthusiasts out there? We are plea...
# 4   As we approach the end of January we wanted to...
# 5   We are so happy to announce that VET TEC benef...
# 6   We are happy to announce that our Dallas campu...
# 7   Come join us for the re-opening of our Dallas ...
# 8   Our Placement Team is simply defined as a grou...
# 9   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 10  In the last few months, the US has experienced...
# 11  As the end of military service gets closer, ma...
# 12  What IT Career should I choose?\nIf you’re thi...
# 13  Codeup offers a 13-week training program: Syst...
# 14  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 15                                              video
# 16  Looking for the best data science bootcamp in ...
# 17  Any podcast enthusiasts out there? We are plea...
# 18  With so many tech careers in demand, why choos...
# 19  Did you know that even though we’re an indepen...
# 20  Codeup is moving into another floor of our His...
# 21  Happy Pride Month! Pride Month is a dedicated ...

# %%
# create a clean column with functions applied to original to clean and tokenize content
codeup_df['clean'] = codeup_df.original.apply(lambda x:basic_clean(x)).apply(lambda x:tokenize(x))

# %%
# create stemmed and lemmatized columns with functions applied to original to further clean
codeup_df = codeup_df.assign(stemmed = codeup_df.clean.apply(stem), lemmatized = codeup_df.clean.apply(lemmatize))
codeup_df
# Out:
#                                                 title  \
# 0   VET TEC Funding Now Available For Dallas Veterans
# 1       Dallas Campus Re-opens With New Grant Partner
# 2   Is Codeup the Best Bootcamp in San Antonio…or ...
# 3            Codeup Launches First Podcast: Hire Tech
# 4                   Codeup Start Dates for March 2022
# 5   VET TEC Funding Now Available For Dallas Veterans
# 6       Dallas Campus Re-opens With New Grant Partner
# 7                            Codeup Dallas Open House
# 8   Codeup’s Placement Team Continues Setting Records
# 9   IT Certifications 101: Why They Matter, and Wh...
# 10  A rise in cyber attacks means opportunities fo...
# 11   Use your GI Bill® benefits to Land a Job in Tech
# 12  Which program is right for me: Cyber Security ...
# 13               What the Heck is System Engineering?
# 14     From Speech Pathology to Business Intelligence
# 15                      Boris – Behind the Billboards
# 16  Is Codeup the Best Bootcamp in San Antonio…or ...
# 17           Codeup Launches First Podcast: Hire Tech
# 18        Why Should I Become a System Administrator?
# 19        Announcing our Candidacy for Accreditation!
# 20  Codeup Takes Over More of the Historic Vogue B...
# 21  Inclusion at Codeup During Pride Month (and Al...
#
#                                                  link  \
# 0   https://codeup.com/codeup-news/vet-tec-funding...
# 1   https://codeup.com/codeup-news/dallas-campus-r...
# 2   https://codeup.com/codeup-news/is-codeup-the-b...
# 3   https://codeup.com/codeup-news/codeup-launches...
# 4   https://codeup.com/codeup-news/codeup-start-da...
# 5   https://codeup.com/codeup-news/vet-tec-funding...
# 6   https://codeup.com/codeup-news/dallas-campus-r...
# 7   https://codeup.com/dallas-newsletter/codeup-da...
# 8   https://codeup.com/codeup-news/codeups-placeme...
# 9   https://codeup.com/it-training/it-certificatio...
# 10  https://codeup.com/cybersecurity/a-rise-in-cyb...
# 11  https://codeup.com/codeup-news/use-your-gi-bil...
# 12  https://codeup.com/tips-for-prospective-studen...
# 13  https://codeup.com/it-training/what-the-heck-i...
# 14  https://codeup.com/alumni-stories/from-speech-...
# 15  https://codeup.com/behind-the-billboards/boris...
# 16  https://codeup.com/codeup-news/is-codeup-the-b...
# 17  https://codeup.com/codeup-news/codeup-launches...
# 18  https://codeup.com/tips-for-prospective-studen...
# 19  https://codeup.com/codeup-news/codeup-candidat...
# 20  https://codeup.com/codeup-news/codeup-takes-ov...
# 21  https://codeup.com/codeup-news/inclusion-at-co...
#
#                                              original  \
# 0   We are so happy to announce that VET TEC benef...
# 1   We are happy to announce that our Dallas campu...
# 2   Looking for the best data science bootcamp in ...
# 3   Any podcast enthusiasts out there? We are plea...
# 4   As we approach the end of January we wanted to...
# 5   We are so happy to announce that VET TEC benef...
# 6   We are happy to announce that our Dallas campu...
# 7   Come join us for the re-opening of our Dallas ...
# 8   Our Placement Team is simply defined as a grou...
# 9   AWS, Google, Azure, Red Hat, CompTIA…these are...
# 10  In the last few months, the US has experienced...
# 11  As the end of military service gets closer, ma...
# 12  What IT Career should I choose?\nIf you’re thi...
# 13  Codeup offers a 13-week training program: Syst...
# 14  By: Alicia Gonzalez\nBefore Codeup, I was a ho...
# 15                                              video
# 16  Looking for the best data science bootcamp in ...
# 17  Any podcast enthusiasts out there? We are plea...
# 18  With so many tech careers in demand, why choos...
# 19  Did you know that even though we’re an indepen...
# 20  Codeup is moving into another floor of our His...
# 21  Happy Pride Month! Pride Month is a dedicated ...
#
#                                                 clean  \
# 0   we are so happy to announce that vet tec benef...
# 1   we are happy to announce that our dallas campu...
# 2   looking for the best data science bootcamp in ...
# 3   any podcast enthusiasts out there we are pleas...
# 4   as we approach the end of january we wanted to...
# 5   we are so happy to announce that vet tec benef...
# 6   we are happy to announce that our dallas campu...
# 7   come join us for the reopening of our dallas c...
# 8   our placement team is simply defined as a grou...
# 9   aws google azure red hat comptiathese are big ...
# 10  in the last few months the us has experienced ...
# 11  as the end of military service gets closer man...
# 12  what it career should i choose\nif youre think...
# 13  codeup offers a 13week training program system...
# 14  by alicia gonzalez\nbefore codeup i was a home...
# 15                                              video
# 16  looking for the best data science bootcamp in ...
# 17  any podcast enthusiasts out there we are pleas...
# 18  with so many tech careers in demand why choose...
# 19  did you know that even though were an independ...
# 20  codeup is moving into another floor of our his...
# 21  happy pride month pride month is a dedicated t...
#
#                                               stemmed  \
# 0   we are so happi to announc that vet tec benefi...
# 1   we are happi to announc that our dalla campu r...
# 2   look for the best data scienc bootcamp in the ...
# 3   ani podcast enthusiast out there we are pleas ...
# 4   as we approach the end of januari we want to l...
# 5   we are so happi to announc that vet tec benefi...
# 6   we are happi to announc that our dalla campu r...
# 7   come join us for the reopen of our dalla campu...
# 8   our placement team is simpli defin as a group ...
# 9   aw googl azur red hat comptiathes are big name...
# 10  in the last few month the us ha experienc doze...
# 11  as the end of militari servic get closer mani ...
# 12  what it career should i choos if your think ab...
# 13  codeup offer a 13week train program system eng...
# 14  by alicia gonzalez befor codeup i wa a home he...
# 15                                              video
# 16  look for the best data scienc bootcamp in the ...
# 17  ani podcast enthusiast out there we are pleas ...
# 18  with so mani tech career in demand whi choos s...
# 19  did you know that even though were an independ...
# 20  codeup is move into anoth floor of our histor ...
# 21  happi pride month pride month is a dedic time ...
#
#                                            lemmatized
# 0   we are so happy to announce that vet tec benef...
# 1   we are happy to announce that our dallas campu...
# 2   looking for the best data science bootcamp in ...
# 3   any podcast enthusiast out there we are please...
# 4   a we approach the end of january we wanted to ...
# 5   we are so happy to announce that vet tec benef...
# 6   we are happy to announce that our dallas campu...
# 7   come join u for the reopening of our dallas ca...
# 8   our placement team is simply defined a a group...
# 9   aws google azure red hat comptiathese are big ...
# 10  in the last few month the u ha experienced doz...
# 11  a the end of military service get closer many ...
# 12  what it career should i choose if youre thinki...
# 13  codeup offer a 13week training program system ...
# 14  by alicia gonzalez before codeup i wa a home h...
# 15                                              video
# 16  looking for the best data science bootcamp in ...
# 17  any podcast enthusiast out there we are please...
# 18  with so many tech career in demand why choose ...
# 19  did you know that even though were an independ...
# 20  codeup is moving into another floor of our his...
# 21  happy pride month pride month is a dedicated t...
